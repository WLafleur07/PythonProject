# %% [markdown]
# # Converts Excel Files to CSV format

# %%
import sys
#!{sys.executable} -m pip install openpyxl
import pandas as pd # using pandas to read from the excel sheets and then convert it
import openpyxl
# Out:
# ...
#      |████████████████████████████████| 243 kB 4.4 MB/s eta 0:00:01
# ...
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8913 sha256=8b2635f2a4a497d941fe7e57c5bd5f794590a41dd888adb8ec3d07017d3c4d6d
#   Stored in directory: /home/jovyan/.cache/pip/wheels/e2/bd/55/048b4fd505716c4c298f42ee02dffd9496bb6d212b266c7f31
# Successfully built et-xmlfile
# ...

# %%
read_file = pd.read_excel("Sample.xlsx")

# %%
read_file.to_csv("Converted.csv", index=None,header=True)

# %%
df = pd.DataFrame(pd.read_csv("Converted.csv"))

# %%
df
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380      Clay Rozendal
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3    -213.25   38.94     35  Nunavut          Storage & Organization  \
# 0  293   457.8100  208.16  68.02  Nunavut                      Appliances
# ...
